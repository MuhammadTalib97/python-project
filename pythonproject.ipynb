# %%
import sqlite3 as sql
con=sql.connect(database="studentdb.sqlite")
cursor=con.cursor()
try:
    cursor.execute("create table students(stu_id int,stu_name text,stu_mob text,stu_course text,course_fee int,bal int)")
    cursor.execute("create table course(course_name text primary key,course_fee int)")
except Exception as e:
    print(e)
con.commit()
con.close()
# Out:
# table students already exists

# %%
from tkinter import *
from tkinter import messagebox
from tkinter.ttk import Combobox
import pyttsx3
win =Tk()
win.state('zoomed')
win.configure(bg='powder blue')
header_frm=Frame(win)
header_frm.configure(bg='pink')
header_frm.place(x=0,y=0,relwidth=1,relheight=0.2)
title_lbl=Label(header_frm,text='student mgt system',bg='pink',font=('',60,'bold','underline'))
title_lbl.pack()

def mainbody():
    def reset():
        user_entry.delete(0,'end')
        pass_entry.delete(0,'end')
        user_entry.focus()
        
    def login():
        u=user_entry.get()
        p=pass_entry.get()
        if(len(u)==0 or len(p)==0):
            messagebox.showwarning('validation',"username/password cannot be empty")
        else:
            if(u=='admin' and p=='admin'):
                frm.destroy()
                loginbody()
                # talk()
            else:
                messagebox.showerror('validation',"invalid username/password")
    # def talk():
    #     engine = pyttsx3.init()     
    #     voices = engine.getProperty('voices')       #getting details of current voice
    #     #engine.setProperty('voice', voices[0].id)  #changing index, changes voices. o for male
    #     engine.setProperty('voice', voices[1].id)
    #     engine.setProperty('rate',100)     
    #     engine.say("welcome admin")
    #     engine.runAndWait()
    #     engine.stop()              
    frm=Frame(win)
    frm.configure(bg='powder blue')
    frm.place(x=0,rely=0.2,relwidth=1,relheight=0.8)
    
    user_lbl=Label(frm,text='username:',font=('',25,'bold'),bg='powder blue')
    user_lbl.place(relx=0.4,rely=0.2)
    
    user_entry=Entry(frm,font=('',20),bd=7)
    user_entry.focus() #automatic cusor aa jaaega us  text field m
    user_entry.place(relx=0.5 ,rely=0.2)
    
    pass_lbl=Label(frm,text='password:',font=('',25,'bold'),bg='powder blue')
    pass_lbl.place(relx=0.4,rely=0.30)
    
    pass_entry=Entry(frm,font=('',20),bd=7,show='*')
    pass_entry.place(relx=0.5 ,rely=.30)
    
    
    login_btn=Button(frm,text="login",font=('',20),bd=7,command=login)
    login_btn.place(relx=0.50,rely=0.4)
    
    reset_btn=Button(frm,text="reset",font=('',20),bd=7,command=reset)
    reset_btn.place(relx=0.60,rely=0.4)

    
    
def loginbody():
    
    def logout():
        frm.destroy()
        mainbody()

        
    def register_student():
        frm.destroy()
        registerstudentbody()
    
    def find_student():
        frm.destroy()
        findstudentbody()
        
    def deposit():
        frm.destroy()
        depositstudentbody()
    
    def add():
        frm.destroy()
        addcoursebody()
    
    
    frm=Frame(win)
    frm.configure(bg='powder blue')
    frm.place(x=0,rely=0.2,relwidth=1,relheight=0.8)
    
    wel_lbl=Label(frm,text="welcome admin",font=('',20),bg='powder blue')
    wel_lbl.place(relx=0,rely=0)
    
    logout_btn=Button(frm,text="logout",font=('',20),bd=7,command=logout)
    logout_btn.place(relx=0.93,rely=0)
    
    reg_btn=Button(frm,text="register student",font=('',20),bd=7,width=15,command=register_student)
    reg_btn.place(relx=0.4,rely=.1)
    
    find_btn=Button(frm,text="find student",font=('',20),bd=7,width=15,command=find_student)
    find_btn.place(relx=0.4,rely=.3)
    
    
    deposit_btn=Button(frm,text="deposit fee",font=('',20),bd=7,width=15,command=deposit)
    deposit_btn.place(relx=0.4,rely=.5)
    
    
    course_btn=Button(frm,text="add course",font=('',20),bd=7,width=15,command=add)
    course_btn.place(relx=0.4,rely=.7)

def registerstudentbody():
    def logout():
        frm.destroy()
        mainbody()
    def home():
        frm.destroy()
        loginbody()
        
    def register_student_db():
        stu_id=id_entry.get()
        stu_name=name_entry.get()
        stu_mob=mob_entry.get()
        stu_crs=course_list.get()
        crs,crs_fee=stu_crs.split()
        stu_fee=fee_entry.get()
        
        
        con=sql.connect(database="studentdb.sqlite")
        cursor=con.cursor()
        cursor.execute("insert into students values(?,?,?,?,?,?)",(stu_id,stu_name,stu_mob,crs,crs_fee,(int(crs_fee)-int(stu_fee))))
        con.commit()
        con.close()
        messagebox.showinfo('registration',"student registered successfully")
        registerstudentbody()
        
        
        
        
    frm=Frame(win)
    frm.configure(bg='powder blue')
    frm.place(x=0,rely=0.2,relwidth=1,relheight=0.8)
    
    wel_lbl=Label(frm,text="welcome Talib",font=('',20),bg='powder blue')
    wel_lbl.place(relx=0,rely=0)
    
    logout_btn=Button(frm,text="logout",font=('',20),bd=7,command=logout)
    logout_btn.place(relx=0.93,rely=0)
    
    home_btn=Button(frm,text="Home",font=('',20),bd=7,command=home)
    home_btn.place(relx=0.85,rely=0)
    
    con=sql.connect(database="studentdb.sqlite")
    cursor=con.cursor()
    cursor.execute("select max(stu_id) from students")
    max_id=cursor.fetchone()
    if(max_id[0]==None):
        stu_id_db=1
    else:
        stu_id_db=max_id[0]+1
        
    stu_id=Label(frm,text="Student Id:",font=('',20),bg='powder blue')
    stu_id.place(relx=0.3,rely=0.01)
    
    id_entry=Entry(frm,font=('',20),bd=7)
    id_entry.place(relx=0.40 ,rely=.01)
    id_entry.insert(0,str(stu_id_db))
    id_entry.configure(state='disabled')
    
    
    
    stu_name=Label(frm,text="Student Name:",font=('',20),bg='powder blue')
    stu_name.place(relx=0.3,rely=0.1)
    
    name_entry=Entry(frm,font=('',20),bd=7)
    name_entry.focus()
    name_entry.place(relx=0.40 ,rely=.1)
    
    stu_mob=Label(frm,text="Student Mob:",font=('',20),bg='powder blue')
    stu_mob.place(relx=0.3,rely=0.2)
    
    mob_entry=Entry(frm,font=('',20),bd=7)
    mob_entry.place(relx=0.40 ,rely=.2)

    stu_course=Label(frm,text="Select Course:",font=('',20),bg='powder blue')
    stu_course.place(relx=0.3,rely=0.3)
    
    
    con=sql.connect(database="studentdb.sqlite")
    cursor=con.cursor()
    cursor.execute("select * from course")
    courses=cursor.fetchall()
    courses.insert(0,"----select---")
    con.close()
    
    course_list =Combobox(frm,values=courses,font=('',20))
    course_list.place(relx=0.40,rely=0.30,height=40,width=288)
    course_list.current(0)
    
    reg_fee=Label(frm,text="Reg Amt:",font=('',20),bg='powder blue')
    reg_fee.place(relx=0.3,rely=0.4)
    
    fee_entry=Entry(frm,font=('',20),bd=7)
    fee_entry.place(relx=0.40 ,rely=.4)
    
    
    reg_btn=Button(frm,text="Register",font=('',20),bd=7,command=register_student_db)
    reg_btn.place(relx=0.46,rely=.5)
    
def findstudentbody():
    def logout():
        frm.destroy()
        mainbody()
    def home():
        frm.destroy()
        loginbody()
   
    def search():
        stu_id=id_entry.get()
        con=sql.connect(database="studentdb.sqlite")
        cursor=con.cursor()
        cursor.execute("select * from students where stu_id=?",(stu_id,))
        row=cursor.fetchone()
        if(row==None):
            messagebox.showwarning("Students","student does not exit")
        else:
            messagebox.showinfo("search",str(row))
    
    frm=Frame(win)
    frm.configure(bg='powder blue')
    frm.place(x=0,rely=0.2,relwidth=1,relheight=0.8)
    
    wel_lbl=Label(frm,text="welcome Talib",font=('',20),bg='powder blue')
    wel_lbl.place(relx=0,rely=0)
    
    logout_btn=Button(frm,text="logout",font=('',20),bd=7,command=logout)
    logout_btn.place(relx=0.93,rely=0)
    
    home_btn=Button(frm,text="Home",font=('',20),bd=7,command=home)
    home_btn.place(relx=0.85,rely=0) 
    
    stu_id=Label(frm,text="Student Id:",font=('',20),bg='powder blue')
    stu_id.place(relx=0.3,rely=0.1)
    
    id_entry=Entry(frm,font=('',20),bd=7)
    id_entry.focus()
    id_entry.place(relx=0.40 ,rely=.1)
    
    search_btn=Button(frm,text="Search",font=('',20),bd=7,command=search)
    search_btn.place(relx=0.45,rely=0.17)
    
def depositstudentbody():
    def logout():
        frm.destroy()
        mainbody()
    def home():
        frm.destroy()
        loginbody()
   
    def fetch_fee(event):#bind ka function aese hi banta h
        stu_id=id_entry.get()
        con=sql.connect(database="studentdb.sqlite")
        cursor=con.cursor()
        cursor.execute("select bal from students where stu_id=?",(stu_id,))
        row=cursor.fetchone()
        if(row==None):
            messagebox.showwarning("","student does not exist")
        else:
            fee_entry.configure(state='normal')
            fee_entry.delete(0,"end")
            fee_entry.insert(0,row[0])
            fee_entry.configure(state='disabled')
            dep_entry.focus()
    def deposit():
        
        stu_id=id_entry.get()
        dep_fee=dep_entry.get()
        con=sql.connect(database="studentdb.sqlite")
        cursor=con.cursor()
        cursor.execute("update students set bal=bal-? where stu_id=?",(int(dep_fee),int(stu_id)))
        con.commit()
        con.close()
        messagebox.showinfo('',"fee deposited")
        frm.destroy()
        depositstudentbody()        
        
    frm=Frame(win)
    frm.configure(bg='powder blue')
    frm.place(x=0,rely=0.2,relwidth=1,relheight=0.8)
    
    wel_lbl=Label(frm,text="welcome Talib",font=('',20),bg='powder blue')
    wel_lbl.place(relx=0,rely=0)
    
    logout_btn=Button(frm,text="logout",font=('',20),bd=7,command=logout)
    logout_btn.place(relx=0.93,rely=0)
    
    home_btn=Button(frm,text="Home",font=('',20),bd=7,command=home)
    home_btn.place(relx=0.85,rely=0) 
    
    stu_id=Label(frm,text="Student Id:",font=('',20),bg='powder blue')
    stu_id.place(relx=0.3,rely=0.1)
    
    id_entry=Entry(frm,font=('',20),bd=7)
    id_entry.focus()  
    id_entry.place(relx=0.40 ,rely=.1)
    id_entry.bind("<FocusOut>",fetch_fee)
    
    stu_fee=Label(frm,text="Remaining Fee:",font=('',20),bg='powder blue')
    stu_fee.place(relx=0.3,rely=0.2)
    
    fee_entry=Entry(frm,font=('',20),bd=7) 
    fee_entry.place(relx=0.40 ,rely=.2)
    
    
    dep_fee=Label(frm,text="Amount:",font=('',20),bg='powder blue')
    dep_fee.place(relx=0.3,rely=0.3)
    
    dep_entry=Entry(frm,font=('',20),bd=7) 
    dep_entry.place(relx=0.40 ,rely=.3)
       
    
    dep_btn=Button(frm,text="Deposit",font=('',20),bd=7,command=deposit)
    dep_btn.place(relx=0.47,rely=0.4)
    
    
def addcoursebody():
    def logout():
        frm.destroy()
        mainbody()
    def home():
        frm.destroy()
        loginbody()
        
    def add_course_db():
        n=name_entry.get()
        n=n.upper()
        f=fee_entry.get()
        if((len(n)==0 or len(f)==0)):
            messagebox.showerror('',"empty field not allowed")
        else:
            con=sql.connect(database="studentdb.sqlite")
            cursor=con.cursor()
            try:
                cursor.execute("insert into course values(?,?)",(n,f))
                con.commit()
                messagebox.showinfo('',"course added")
            except:
                messagebox.showerror("","course name aleady exist")
            con.close()
            frm.destroy()
            addcoursebody()
   
    frm=Frame(win)
    frm.configure(bg='powder blue')
    frm.place(x=0,rely=0.2,relwidth=1,relheight=0.8)
    
    wel_lbl=Label(frm,text="welcome Talib",font=('',20),bg='powder blue')
    wel_lbl.place(relx=0,rely=0)
    
    logout_btn=Button(frm,text="logout",font=('',20),bd=7,command=logout)
    logout_btn.place(relx=0.93,rely=0)
    
    home_btn=Button(frm,text="Home",font=('',20),bd=7,command=home)
    home_btn.place(relx=0.85,rely=0) 
    
    course_name=Label(frm,text="Course Name:",font=('',20),bg='powder blue')
    course_name.place(relx=0.3,rely=0.1)
    
    name_entry=Entry(frm,font=('',20),bd=7)
    name_entry.focus()
    name_entry.place(relx=0.40 ,rely=.1)
    
    
    course_fee=Label(frm,text="Course Fee:",font=('',20),bg='powder blue')
    course_fee.place(relx=0.3,rely=0.2)
    
    fee_entry=Entry(frm,font=('',20),bd=7)
    fee_entry.place(relx=0.40 ,rely=.2)
    
    
    add_btn=Button(frm,text="Add",font=('',20),bd=7,command=add_course_db)
    add_btn.place(relx=0.45,rely=0.28)
       
    

mainbody()
win.mainloop()
